# %% [markdown]
# # Distant Reading,переходим к Python

# %% [markdown]
# ## Как использовать этот код
#
# ### (можно пропустить эту часть, если вы знаете, что такое Jupyter и ipynb-тетрадки -- в таком случае переходите сразу к "Начало работы")
# То, на что вы сейчас смотрите — тетрадка Jupyter Notebook. Это одна из популярных сред для написания и __демонстрации__ кода на Python (и не только). Jupyter запускает питоновский код прямо в браузере (но локально, т.е. код исполняет ваш компьютер, в отличие от, например Google Colab). В Jupyter код можно запускать не целиком, а по ячейкам (в отличие от IDLE).
#
# Пример:

# %%
# ячейка с кодом
text = 'Мы с Даней сегодня тестим инструменты дистант ридинга'
print (text)
# Out:
# Мы с Даней сегодня тестим инструменты дистант ридинга

# %%
# еще одна ячейка с кодом. 
# Пространство имен общее — переменная text была заполнена в предыдущей ячейке
print (text.upper())
# Out:
# МЫ С ДАНЕЙ СЕГОДНЯ ТЕСТИМ ИНСТРУМЕНТЫ ДИСТАНТ РИДИНГА

# %% [markdown]
# Кроме того, ячейки бывают текстовыми — их можно форматировать с помощью формата разметки markdown (.md). Текст, который вы сейчас читаете, а также всякие описания и картинки в предыдущей части этого занятия, написаны как раз в таком формате. Файлы Jupyter Notebook имеют расширение .ipynb и автоматически рендерятся гитхабом. Например, вот эта __[тетрадка](https://github.com/DanilSko/itmo/blob/master/ITMO_practice/BasicProcessing/Basic%20text%20processing%20Danya%20ITMO.ipynb)__  у меня на гитхабе.

# %% [markdown]
# ## Окей, а как я могу запустить код в таком .ipynb?
#
# Есть разные варианты:
#
# ### Через __[Google Colab](https://colab.research.google.com)__.
#
# Google Colab — это гугловский инструмент для написания кода в браузере и запуска прямо на серверах Google (с возможностью бесплатно использовать их вычислительные мощности, в т.ч. графические процессор  — GPU).  Google Colab — родственник Jupyter, они очень похожи. Разница в том, что Jupyter работает локально и использует ваш собственный питон, а Google Colab — это облачный сервис, похожий на Google Docs: вы можете делиться тетрадками и т.д. В Colab можно открыть эту тетрадку, указав ссылку на нее:
#
# ![Colab](pics/github2colab.png)
#
# Просто загрузить .ipynb-файл в Colab тоже можно.
#
# ### Скачать себе .ipynb и открыть в Jupyter
#
# Скачать .ipynb с гитхаба:
#
# ![Raw](pics/raw_download.png)
#
# Поставить Jupyter Notebook по инструкции __[отсюда](https://jupyter.readthedocs.io/en/latest/install.html)__. Открыть терминал (в Windows — командную строку).пойти в папку, внутри которой лежит скачанный .ipynb, написать там jupyter notebook. После этого у вас должно открыться в браузере что-то такое:
#
# ![Colab](pics/jupyter2.png)
#
# Тыкайте на тетрадку -- и все, можно работать в ней, писать код и т.п. Из Jupyter можно выгрузить и отдельно код в виде файла .py (но тогда разделение на ячейки пропадет).
#
# ### Клонировать репозиторий
#
# Чуть более продвинутся версия предыдущего варианта. Делаете
#
# git clone https://github.com/dhhse/dhcourse
#
# И у вас есть этот код, а к тому же и все тексты рядом с ним (в папке texts лежит наш корпус в лемматизированном виде). **Правда, скачиывание через небыстрый интернет может занять сколько-то времени**.
#
# ### Скачать .ipynb и открыть в PyCharm
# Если вы любите популярную у питонистов IDE PyCharm  -- она умеет открывать ipynb. Но для этого все равно нужен установеленный Jupyter. Поэтому надо проделать все то же, что в предыд.пункте, а потом открыть файл в PyCharm.
#
# ### Скачать файл .py из Google Colab или Jupyter и открыть любой IDE (IDLE, PyCharm, что угодно...)
# Из Colab после создания копии вы можете выгрузить не весь .ipynb, а только код в .py. Этот код уже можно запускать где угодно, хоть из командной строки (терминала) вашего компьютера. Но тогда разделение на ячейки опять-таки пропадет.

# %% [markdown]
# # Начало работы

# %% [markdown]
# ## Самый простой пример: работаем в Python с одиночным текстом

# %%
# у себя в репозитории я положил рядом с кодом пример текста — Тайну двух океанов Адамова
# вот так я проверю, что рядом в папке лежит файл с корпусом.
# !ls
# Out:
# 1959_Adamov_Tayna_2_okeanov.txt         pics
# first_dr_notebook_danya.ipynb           practice1.md
# old_large_first_dr_notebook_danya.ipynb texts

# %%
## У тех, кто смотрит в колабе, его, естественно, не будет. В случае, когда нам нужен всего один файл, это можно решить вот стандартный код для загрузки в колаб
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %% [markdown]
#  __[Ссылка на текстовый файл](https://github.com/dhhse/dhcourse/blob/master/dr_practice/1959_Adamov_Tayna_2_okeanov.txt)__.

# %%
# откроем файл в питоне
path_to_file = '1959_Adamov_Tayna_2_okeanov.txt'
dva_okeana = open (path_to_file, 'r')
dva_okeana_kak_stroka = dva_okeana.read()

# %%
## попробуйте вывести тут длину строки с помощью функции len; надо написать len (dva_okeana_kak_stroka) -- так вы передадите в функцию len ваш текст, считанный в сторку

# %%
## попробуйте получить срез из первых 100 символов вашей строки с помощью срезов списка [:]
## т.е. напишите ниже вот это: dva_okeana_kak_stroka [:100]
## и нажмите выполнить
# Out:
# '* ЧАСТЬ ПЕРВАЯ * \n\n\n\n\nГлава I. ПРЕРВАННЫЙ РАЗГОВОР\n\n\n\n\n\n     До рассвета  оставалось уже немного. Из'

# %% [markdown]
# # Сегментация текста

# %% [markdown]
# ## 0. Простейший способ сегментации строки на токены (как бы на слова, но тупее грубее) — питоновский встроенный метод .split:

# %%
dva_okeana_kak_spisok_slov = dva_okeana_kak_stroka.split() ## здесь в качестве аргумента можно воткнуть разделитель; по умолчанию это любое количество пробелов
print ('Примерное количество слов в "Тайне двух океанов":', len (dva_okeana_kak_spisok_slov))
# Out:
# Примерное количество слов в "Тайне двух океанов": 127560

# %%
dva_okeana_kak_spisok_slov[:200]

#type (prest_i_nak_kak_stroka)
# Out:
# ['*',
#  'ЧАСТЬ',
#  'ПЕРВАЯ',
#  '*',
#  'Глава',
#  'I.',
#  'ПРЕРВАННЫЙ',
#  'РАЗГОВОР',
#  'До',
#  'рассвета',
#  'оставалось',
#  'уже',
#  'немного.',
#  'Из',
#  'комнаты',
#  'на',
#  'четырнадцатом',
#  'этаже,',
#  'сквозь',
#  'щелку',
#  'между',
#  'плотными',
#  'портьерами,',
#  'во',
#  'влажную',
#  'темноту',
#  'двора',
#  'пробивалась',
#  'слабая,',
#  'едва',
#  'заметная',
#  'полоска',
#  'света.',
#  'Маленькая',
#  'настольная',
#  'лампа',
#  'под',
#  'низким',
#  'черным',
#  'абажуром',
#  'бросала',
#  'яркий',
#  'конус',
#  'света',
#  'на',
#  'небольшой',
#  'участок',
#  'географической',
#  'карты,',
#  'разложенной',
#  'на',
#  'столе.',
#  'Все',
#  'кругом',
#  'терялось',
#  'в',
#  'густом',
#  'сумраке.',
#  'Два',
#  'человека',
#  'склонились',
#  'над',
#  'картой.',
#  'Их',
#  'лица',
#  'были',
#  'неразличимы,',
#  'в',
#  'полумраке',
#  'мерцали',
#  'лишь',
#  'глаза:',
#  'одни',
#  '--',
#  'узкие,',
#  'косо',
#  'поставленные,',
#  'тусклые,',
#  'равнодушные;',
#  'другие',
#  '--',
#  'большие,',
#  'горящие,',
#  'глубоко',
#  'запавшие',
#  'в',
#  'черноту',
#  'глазниц.',
#  'Смутными',
#  'контурами',
#  'проступали',
#  'фигуры',
#  'этих',
#  'людей.',
#  'Сидевший',
#  'у',
#  'стола,',
#  'небольшого',
#  'роста,',
#  'коренастый',
#  'и',
#  'сильный,',
#  'с',
#  'выправкой',
#  'военного,',
#  'поднял',
#  'голову',
#  'и,',
#  'не',
#  'снимая',
#  'пальца',
#  'с',
#  'точки',
#  'в',
#  'центре',
#  'Атлантического',
#  'океана,',
#  'спросил:',
#  '--',
#  'Точные',
#  'координаты',
#  'Саргассовой',
#  'станции',
#  'неизвестны?',
#  '--',
#  'Нет,',
#  'капитан.',
#  '--',
#  'Я',
#  'вас',
#  'неоднократно',
#  'просил,',
#  'Крок,',
#  'не',
#  'называть',
#  'меня',
#  'так.',
#  'Крок',
#  'выпрямился.',
#  'Он',
#  'был',
#  'очень',
#  'высокого',
#  'роста,',
#  'широкий',
#  'в',
#  'кости,',
#  'с',
#  'длинными',
#  'руками.',
#  '--',
#  'Простите,',
#  'Матвей',
#  'Петрович,--',
#  'проговорил',
#  'он',
#  'глухим',
#  'голосом.',
#  '--',
#  'Я',
#  'все',
#  'забываю',
#  'об',
#  'этом.',
#  '--',
#  'Ваша',
#  'забывчивость',
#  'может',
#  'нам',
#  'когда-нибудь',
#  'очень',
#  'дорого',
#  'обойтись.',
#  'Если',
#  'вы',
#  'для',
#  'меня',
#  'Крок,',
#  'и',
#  'только',
#  'Крок,',
#  'то',
#  'и',
#  'я',
#  'для',
#  'вас',
#  '--',
#  'запомните',
#  'раз',
#  'н',
#  'навсегда!--',
#  'всего',
#  'лишь',
#  'якут,',
#  'инженер,',
#  'Матвей',
#  'Петрович',
#  'Ивашев.',
#  'Матвей',
#  'Петрович']

# %% [markdown]
# ### попробуем получить список уникальных слов:

# %%
dva_okeana_kak_mnojestvo_slov = set(dva_okeana_kak_spisok_slov) ## превратим список в множество
len (dva_okeana_kak_mnojestvo_slov) ## получим число уникальных слов
# Out:
# 36023

# %%
dva_okeana_kak_spisok_unikalnyh_slov = list (dva_okeana_kak_mnojestvo_slov)
(dva_okeana_kak_spisok_unikalnyh_slov).sort()
dva_okeana_kak_spisok_unikalnyh_slov [:1000]
# Out:
# ['!',
#  '"--',
#  '"...',
#  '"...гассово',
#  '"5',
#  '"I)',
#  '"А',
#  '"Авария!',
#  '"Авария...',
#  '"Ага!',
#  '"Айсберг"',
#  '"Ах,',
#  '"Бигль".',
#  '"Бу-бу-бу...',
#  '"Бу-бу-бу..."',
#  '"Бу-бу...',
#  '"Вальдивией"',
#  '"Велыкий',
#  '"Вероятно,--',
#  '"Винт!..',
#  '"Витязе"',
#  '"Внимание!',
#  '"Вот',
#  '"Выберемся"!',
#  '"Гипобития',
#  '"Главный',
#  '"Голос',
#  '"Гольфстрим".',
#  '"Гольфштрем".',
#  '"Готовиться',
#  '"Даже',
#  '"Диоген"',
#  '"Диогена"',
#  '"Диогена",',
#  '"Диогена".',
#  '"Диогене"',
#  '"Диогену",',
#  '"Для',
#  '"Дюзовая',
#  '"Если',
#  '"Ждем.',
#  '"За',
#  '"Заветы',
#  '"Задний',
#  '"Зажечь',
#  '"Зачем',
#  '"Здесь',
#  '"Знак',
#  '"Идзумо"',
#  '"Из',
#  '"Испортилось',
#  '"К"..',
#  '"Кажется,',
#  '"Как',
#  '"Какая',
#  '"Какой',
#  '"Канаты,',
#  '"Кашалот!"',
#  '"Кипящий"',
#  '"Командир',
#  '"Куда',
#  '"Курс',
#  '"Леди',
#  '"Львиная',
#  '"Львиной',
#  '"Макроцистис',
#  '"Мало',
#  '"Марии-Антуанетты",',
#  '"Марию-Антуанетту",',
#  '"Млечного',
#  '"Млечным',
#  '"Москва,',
#  '"Мы',
#  '"Надо',
#  '"Не',
#  '"Нельзя!..',
#  '"Немедленно!"',
#  '"Но',
#  '"Новое',
#  '"Ну,',
#  '"О',
#  '"Обвал..."',
#  '"Обнимай',
#  '"Обнять..."',
#  '"Они',
#  '"Осторожно!',
#  '"Ответ',
#  '"Откуда',
#  '"Ох!"',
#  '"ПИОНЕР"',
#  '"Павлик,',
#  '"Пи..."',
#  '"Пионер',
#  '"Пионер!"',
#  '"Пионер"',
#  '"Пионер"!',
#  '"Пионер"!..',
#  '"Пионер",',
#  '"Пионер",--',
#  '"Пионер".',
#  '"Пионер"...',
#  '"Пионер"..."',
#  '"Пионер;"',
#  '"Пионера"',
#  '"Пионера",',
#  '"Пионера".',
#  '"Пионера"?',
#  '"Пионере"',
#  '"Пионере",',
#  '"Пионеров"',
#  '"Пионером"',
#  '"Пионеру"',
#  '"Пионеру",',
#  '"Пионеру".',
#  '"Пиротехника"!',
#  '"Победители',
#  '"Правила',
#  '"Пробоина,--',
#  '"Проскочить!',
#  '"Радио,',
#  '"Радиограмма.',
#  '"Разведчик',
#  '"Реве',
#  '"Роб-Рой"',
#  '"Сазанами',
#  '"Санта-Марии"',
#  '"Санта-Мария",',
#  '"Свет!..',
#  '"Скворешня",--',
#  '"Смерть!"',
#  '"Срочно!',
#  '"Срочно!"',
#  '"Столкновение...',
#  '"Строгий"',
#  '"Т"...',
#  '"Тайна',
#  '"Тоже',
#  '"Уже',
#  '"Уф!"',
#  '"Ф.',
#  '"ЧЕЛОВЕК',
#  '"Человек!',
#  '"Черный',
#  '"Что',
#  '"ЭЦИТ...',
#  '"Эль-пополо",',
#  '"Это',
#  '"Я',
#  '"Ямато"',
#  '"Ямато",',
#  '"Ямато".',
#  '"безграмотные"',
#  '"белом',
#  '"белых',
#  '"в',
#  '"винцо"',
#  '"вкл"',
#  '"вкл".',
#  '"возмутительной",',
#  '"возмутительном',
#  '"вольно",',
#  '"вот',
#  '"выкл".',
#  '"гигантские',
#  '"дам"',
#  '"даму"',
#  '"десять',
#  '"есть,',
#  '"живой',
#  '"инцидентах",',
#  '"караул"...',
#  '"кислород"',
#  '"конкурс',
#  '"координаты"...',
#  '"координаты"?',
#  '"краб"',
#  '"крабами"',
#  '"крайним',
#  '"легкомысленно"',
#  '"лед"',
#  '"лягушек".',
#  '"лягушки"',
#  '"малый',
#  '"мальчик',
#  '"маслом",--',
#  '"материковым',
#  '"мовы"',
#  '"на',
#  '"не',
#  '"никому-никому',
#  '"он',
#  '"органика".',
#  '"острова"?',
#  '"охотники"',
#  '"папаши",--',
#  '"питание",',
#  '"по',
#  '"подводным',
#  '"поймать',
#  '"полосе',
#  '"последнего',
#  '"прожекторы"',
#  '"прострочены"',
#  '"противника".',
#  '"пуговиц".',
#  '"реакция',
#  '"ридной',
#  '"русскую",',
#  '"сказочником",',
#  '"срыве',
#  '"термитной',
#  '"точные',
#  '"ты".',
#  '"ундервуд",',
#  '"ундервуда"',
#  '"ундервудам".',
#  '"ура"',
#  '"ура".',
#  '"успехи"',
#  '"фантазером"...',
#  '"хорошо",',
#  '"цивилизаторы"',
#  '"шалаша"',
#  "'--",
#  '(-273,2',
#  '(1)',
#  '(1)Современное',
#  '(2)',
#  '(3)',
#  '(4)...--',
#  '(6000',
#  '(Капитан',
#  '(Кроку',
#  '(Слышите?',
#  '(алюминия,',
#  '(газопроводная',
#  '(дюралюминий)',
#  '(микроскопические',
#  '(окалина,',
#  '(раструб).',
#  '*',
#  ',части',
#  ',чем',
#  '-',
#  '--',
#  '---------------------------------------------------------------',
#  '.',
#  '..',
#  '...Милый',
#  '...Мы',
#  '...бина',
#  '...цать',
#  '...чно',
#  '.Чижов,',
#  '.в',
#  '.на',
#  '.разбросанных',
#  '.тяжел',
#  '.упорство,',
#  '.этому',
#  '1-го',
#  '1.',
#  '10.',
#  '11.',
#  '12.',
#  '13.',
#  '14.',
#  '142.',
#  '15.',
#  '189,',
#  '19...',
#  '1917',
#  '2',
#  '2)',
#  '2-го',
#  '2.',
#  '23',
#  '271,9',
#  '3)',
#  '3.',
#  '32',
#  '3500',
#  '36',
#  '4.',
#  '46',
#  '5',
#  '5.',
#  '6.',
#  '7',
#  '7.',
#  '7500',
#  '8.',
#  '9.',
#  '?',
#  '?..',
#  'Chiasmodon',
#  'I.',
#  'II"',
#  'II.',
#  'III.',
#  'IV.',
#  'IX.',
#  'Lammelibrachtata',
#  'Lammelibranchiata',
#  'Lammelibranchiata.',
#  'Lordkipanidze!',
#  'Lordkipanidze.',
#  'Pyrozoma',
#  'V.',
#  'VI.',
#  'VII.',
#  'VIII.',
#  'XI.',
#  'XII.',
#  'XIII.',
#  'XIX',
#  'atlantica!',
#  'cephala',
#  'cephala.',
#  'niger!..',
#  'x',
#  '°С),',
#  '°С,',
#  'А',
#  'А!',
#  'А!..',
#  'А,',
#  'А-а-а!',
#  'А-а-а!..',
#  'А-а-а...',
#  'А-а-ах!',
#  'А-а...',
#  'А?',
#  'А?..',
#  'АТАКА',
#  'Абрамович!',
#  'Абрамович!..',
#  'Абрамович,--',
#  'Абрамович...',
#  'Абрамович?',
#  'Абрамовичу',
#  'Абрамовичу,',
#  'Абросимов',
#  'Абросимов,',
#  'Абросимов,--',
#  'Абросимова',
#  'Абросимова.',
#  'Абросимовым,',
#  'Абросимовым-отцом',
#  'Абросимовыми,',
#  'Абросимовых.',
#  'Абсолютно',
#  'Абсолютно!',
#  'Абсолютно!..',
#  'Абсолютно.',
#  'Авария',
#  'Авария!".',
#  'Авиастроительный',
#  'Аврала',
#  'Автор',
#  'Ага!',
#  'Ага!..',
#  'Ага,',
#  'Агуласской',
#  'Азиатском',
#  'Азию...',
#  'Ай',
#  'Айдзава',
#  'Айдзава,',
#  'Айдзава...',
#  'Айсберг',
#  'Айсберг,',
#  'Аккумуляторы',
#  'Активной',
#  'Актиния',
#  'Акула',
#  'Акула,',
#  'Акула...',
#  'Акула?',
#  'Акулы',
#  'Акулы,',
#  'Акустики',
#  'Александр',
#  'Алло!',
#  'Америк,',
#  'Америке',
#  'Америке,',
#  'Америки',
#  'Америки,',
#  'Америки.',
#  'Америки:',
#  'Америку.',
#  'Аморфная',
#  'Ангата',
#  'Ангата,',
#  'Андреи',
#  'Андрей',
#  'Андрей,',
#  'Андрея',
#  'Андрея!',
#  'Анна',
#  'Анна!',
#  'Анна!..',
#  'Анной',
#  'Анны',
#  'Антарктике,',
#  'Антарктики,',
#  'Антарктики.',
#  'Антарктического',
#  'Антарктическом,',
#  'Антильское',
#  'Антипатия',
#  'Аппарат',
#  'Арктике.',
#  'Арктики',
#  'Арсен',
#  'Арсен...',
#  'Арсена',
#  'Арсеном',
#  'Арсену',
#  'Археология?..',
#  'Архимеда:',
#  'Асцидия,',
#  'Атлантике',
#  'Атлантике,',
#  'Атлантики,',
#  'Атлантики.',
#  'Атлантику,',
#  'Атлантический',
#  'Атлантического',
#  'Атлантического,',
#  'Атлантическое',
#  'Атмосфера',
#  'Атоллы',
#  'Африке,',
#  'Африки,',
#  'Африки.',
#  'Ах',
#  'Ах!..',
#  'Ах,',
#  'Ах-х-х!',
#  'Ахтерштевень',
#  'Аху-аху-татана,',
#  'БЕРЕГАМ',
#  'БИТВА',
#  'БОЙ',
#  'БОМБАРДИРОВКА',
#  'БОРТОМ"',
#  'БОРТУ',
#  'БУМАГИ',
#  'Багамских',
#  'Багровая',
#  'Багровый',
#  'Балтийского',
#  'Балтийском',
#  'Баренцева',
#  'Баренцево',
#  'Баритон',
#  'Барракуда',
#  'Барракуда...',
#  'Батьке',
#  'Батюшки!',
#  'Баффинова',
#  'Баффиновой',
#  'Бегло',
#  'Бегу',
#  'Бедный',
#  'Бедный,',
#  'Бедным',
#  'Бежать',
#  'Бежим,',
#  'Без',
#  'Безграничные',
#  'Бездельной',
#  'Безмолвие',
#  'Безумный',
#  'Белоголовому,',
#  'Белоголовый',
#  'Белоголовый,',
#  'Белоголовый.',
#  'Белоснежный',
#  'Белые',
#  'Белый',
#  'Беляев,',
#  'Беляеву',
#  'Бердвууд,',
#  'Бердвууд?',
#  'Береги',
#  'Берегитесь!',
#  'Бережно',
#  'Берингова',
#  'Берингова,',
#  'Беспокойство',
#  'Беспорядочная',
#  'Бессвязные',
#  'Бесчисленные',
#  'Бить',
#  'Бичо!',
#  'Бичо,',
#  'Благодарю',
#  'Благодарю,',
#  'Благодаря',
#  'Благослови,',
#  'Благословляю!',
#  'Бледная',
#  'Бледный,',
#  'Блейхмана',
#  'Блейхмана.',
#  'Ближайшие',
#  'Ближе',
#  'Близко,',
#  'Богров',
#  'Богров,',
#  'Богров.',
#  'Богрова',
#  'Богрова,',
#  'Богрова.',
#  'Богрова...',
#  'Богрова:',
#  'Богрову',
#  'Богровым,',
#  'Боевые',
#  'Боже',
#  'Бой',
#  'Более',
#  'Болтун!',
#  'Боль',
#  'Большая',
#  'Большая!',
#  'Большая...',
#  'Больше',
#  'Больше,',
#  'Большее',
#  'Большие',
#  'Большими',
#  'Большинство',
#  'Большого',
#  'Большое',
#  'Большое,',
#  'Большой',
#  'Бомбили',
#  'Бона',
#  'Борисович!',
#  'Борисович,',
#  'Борисович,--',
#  'Борисович.',
#  'Борисович...',
#  'Борисович?',
#  'Борисовича.',
#  'Бормотание',
#  'Борьба',
#  'Боюсь',
#  'Боюсь,',
#  'Боязно...',
#  'Бр-р!',
#  'Браво,',
#  'Бригада',
#  'Британских',
#  'Бронштейн',
#  'Бронштейн!',
#  'Бронштейн,',
#  'Бросайте',
#  'Бросив',
#  'Бросился',
#  'Бросился,',
#  'Бросить',
#  'Брось,',
#  'Бросьте',
#  'Брюхо',
#  'Будем',
#  'Будет',
#  'Будете',
#  'Буду',
#  'Будучи',
#  'Будь',
#  'Будьте',
#  'Буи',
#  'Бульон,',
#  'Буняк',
#  'Буняк!',
#  'Буняк,',
#  'Буняка',
#  'Буняка,',
#  'Буняка.',
#  'Бывал',
#  'Бывали,',
#  'Был',
#  'Была',
#  'Были',
#  'Было',
#  'Быстро',
#  'Быстро,',
#  'Быстрота',
#  'Быстроту',
#  'Бьюкенен',
#  'В',
#  'ВЗРЫВА',
#  'ВКП(б)',
#  'ВОДОРОСЛЕЙ',
#  'ВСТРЕЧИ',
#  'ВТОРАЯ.',
#  'ВЫХОДА',
#  'Важна',
#  'Важно,',
#  'Вайгу',
#  'Вайгу,',
#  'Вайгу...',
#  'Вальпараисо,',
#  'Вальтера',
#  'Валяй,',
#  'Вам',
#  'Вам,',
#  'Вас...',
#  'Василий',
#  'Васильевич',
#  'Васильевич!',
#  'Васильевич,',
#  'Васильевич,--',
#  'Васильевич.',
#  'Васильевич...',
#  'Васильевич:',
#  'Васильевич?',
#  'Васильевича',
#  'Вахтенный',
#  'Вахту',
#  'Ваша',
#  'Ваше',
#  'Ваши',
#  'Вашим',
#  'Вашими',
#  'Вверх!',
#  'Вглядевшись,',
#  'Вдали',
#  'Вдали,',
#  'Вдвоем',
#  'Вдоль',
#  'Вдруг',
#  'Ведь',
#  'Ведь,',
#  'Вездесущие',
#  'Великого',
#  'Великой',
#  'Великолепно!',
#  'Великолепно,',
#  'Величайшая',
#  'Величина',
#  'Веревка',
#  'Веревка,',
#  'Вернее,',
#  'Верно!',
#  'Верно,',
#  'Вернувшись',
#  'Вернулись',
#  'Вероятно,',
#  'Верхние',
#  'Веселей',
#  'Весело',
#  'Веселье',
#  'Весенний,',
#  'Вести',
#  'Весь',
#  'Весьма',
#  'Ветер',
#  'Веточка',
#  'Ветров',
#  'Взвился',
#  'Взволнованные',
#  'Взволнованный',
#  'Взгромоздив',
#  'Взмахнув,',
#  'Взорвать',
#  'Взрыв',
#  'Взрывчатых',
#  'Взять',
#  'Видел!',
#  'Видим',
#  'Видимо,',
#  'Видите',
#  'Видите,',
#  'Видите?..',
#  'Видишь',
#  'Видишь,',
#  'Видишь:',
#  'Видно',
#  'Видны',
#  'Видя,',
#  'Вие-хоа.',
#  'Вижу',
#  'Вижу,',
#  'Вижу.',
#  'Виктор',
#  'Виктору',
#  'Вильнув',
#  'Виноват,',
#  'Винт',
#  'Винт...',
#  'Винты',
#  'Включайте',
#  'Включаю',
#  'Включи',
#  'Включив',
#  'Включить',
#  'Владеет',
#  'Владивосток',
#  'Владивосток,',
#  'Владивосток.',
#  'Владивостока',
#  'Владивостока,',
#  'Владивостока.',
#  'Владивостоке',
#  'Владивостоке!',
#  'Владивостоке.',
#  'Владивостоке...',
#  'Владивостоком',
#  'Власьев',
#  'Власьев,',
#  'Власьева,',
#  'Власьевым,',
#  'Вложив',
#  'Вместе',
#  'Вмешался',
#  'Вне',
#  'Внезапно',
#  'Внезапно,',
#  'Вниз!',
#  'Внизу',
#  'Внизу,',
#  'Внимание!',
#  'Внимание!..',
#  'Внимание,',
#  'Внимательно',
#  'Во',
#  'Во-вторых,',
#  'Во-первых,',
#  'Во-первых,--',
#  'Вода',
#  'Вода,',
#  'Водолаз',
#  'Водолазы',
#  'Водоросли',
#  'Водоросли?!',
#  'Воды',
#  'Военно-Морских',
#  'Военно-Морского',
#  'Военно-инженерную',
#  'Военные',
#  'Возвращайтесь',
#  'Возвращайтесь!',
#  'Возвращайтесь...',
#  'Возвращаясь',
#  'Возгласами',
#  'Возгласы',
#  'Воздвигнем',
#  'Воздух',
#  'Воздух?',
#  'Воздуха',
#  'Воздуха?',
#  'Возле',
#  'Возможно,',
#  'Возможно,--',
#  'Возмущенный',
#  'Возня',
#  'Возражений',
#  'Возраст',
#  'Возьми',
#  'Возьми,',
#  'Возьмите',
#  'Возьмите,',
#  'Войдите!',
#  'Войдя',
#  'Вокруг',
#  'Волгой.',
#  'Волнение',
#  'Волну',
#  'Волнуясь',
#  'Вольно,',
#  'Вон',
#  'Вон,',
#  'Воображения',
#  'Вообще',
#  'Вопреки',
#  'Вопрос',
#  'Воронежский',
#  'Воронцов',
#  'Воронцов".',
#  'Воронцов,',
#  'Воронцов.',
#  'Воронцова',
#  'Воронцова,',
#  'Воронцову',
#  'Воронцову,',
#  'Восемнадцать',
#  'Восемь',
#  'Восемьдесят',
#  'Воспоминания',
#  'Восток!',
#  'Востока',
#  'Востока.',
#  'Востоке.',
#  'Восточной',
#  'Вот',
#  'Вот!',
#  'Вот!..--',
#  'Вот,',
#  'Вот-вот,',
#  'Вот-с!',
#  'Вот.',
#  'Вот...',
#  'Воцарилось',
#  'Вошел',
#  'Вперед',
#  'Вперед!..',
#  'Вперед,',
#  'Впереди',
#  'Впереди,',
#  'Вполголоса',
#  'Вполз',
#  'Вполне',
#  'Вполне,',
#  'Впрочем,',
#  'Впрочем,--',
#  'Впустив',
#  'Враг',
#  'Враги',
#  'Временами',
#  'Времени?',
#  'Время',
#  'Врешь!..',
#  'Врешь...',
#  'Вряд',
#  'Все',
#  'Все!',
#  'Все,',
#  'Все-таки',
#  'Все?',
#  'Всегда',
#  'Всего',
#  'Всеевропейская',
#  'Всей',
#  'Всем',
#  'Всем,',
#  'Всеми',
#  'Всему',
#  'Всех',
#  'Вскоре',
#  'Вслед',
#  'Вследствие',
#  'Вспомнив,',
#  'Вспыхнувшие',
#  'Вспыхнули',
#  'Встревоженные,',
#  'Встревоженный',
#  'Встретив',
#  'Встретимся',
#  'Встреча',
#  'Встречая',
#  'Вступили',
#  'Всю',
#  'Всюду',
#  'Всюду,',
#  'Вся',
#  'Вторично',
#  'Второй',
#  'Вуда',
#  'Вход',
#  'Входи',
#  'Входи,',
#  'Входите,',
#  'Вы',
#  'Вы,',
#  'Вы...',
#  'Выберемся,--',
#  'Выбрать',
#  'Вывести',
#  'Выгребай',
#  'Выдвинул',
#  'Выдели',
#  'Выделите',
#  'Выдержит',
#  'Выжимаемый',
#  'Вызвать',
#  'Вызовите',
#  'Вызывайте',
#  'Вызываю',
#  'Выкладывай,',
#  'Выключаю',
#  'Выключенный',
#  'Выключив',
#  'Выключить',
#  'Вынув',
#  'Выпей,',
#  'Выпейте',
#  'Выползаю!',
#  'Выпустив',
#  'Выпустил',
#  'Выпустите',
#  'Выражаю',
#  'Вырвал',
#  'Высадив',
#  'Высланный',
#  'Выслать',
#  'Выслушивая',
#  'Высокие,',
#  'Высокий',
#  'Высоко',
#  'Высоко,',
#  'Высота',
#  'Выступая',
#  'Выступивший',
#  'Высунувшись',
#  'Вытянув',
#  'Выхватив',
#  'Выход',
#  'Выходило,',
#  'Выходит,',
#  'Выходная',
#  'Выше',
#  'Вышел',
#  'ГИБЕЛЬ"ДИОГЕНА"',
#  'ГЛУБИН',
#  'ГОРЕЛОВ',
#  'Ганс',
#  'Гарди,',
#  'Гармоничное',
#  'Гарпун',
#  'Гасить',
#  'Гвинейского',
#  'Где',
#  'Где,',
#  'Где-то',
#  'Где?',
#  'Генерал...',
#  'Гениально!',
#  'Гениальный,',
#  'Гести',
#  'Гести.',
#  'Гибралтар',
#  'Гибралтаре',
#  'Гибралтарский',
#  'Гибралтарского',
#  'Гибралтарском',
#  'Гибралтару?',
#  'Гигант',
#  'Гигант,',
#  'Гигантские',
#  'Гигантского',
#  'Гидроплан!',
#  'Гирина,',
#  'Глава',
#  'Главного',
#  'Главное',
#  'Главному',
#  'Главный',
#  'Гладкое',
#  'Глаза',
#  'Глазам',
#  'Глиссер',
#  'Глоток',
#  'Глубина',
#  'Глубоко',
#  'Глупости!..',
#  'Глухие',
#  'Глухой',
#  'Гляди,',
#  'Глядите,--',
#  'Гм,',
#  'Гм..',
#  'Гм...',
#  'Гнусавый',
#  'Говори,',
#  'Говори-выкладывай!',
#  'Говорил',
#  'Говорили,',
#  'Говорит',
#  'Говорит,',
#  'Говорит...',
#  'Говорите',
#  'Говорите,',
#  'Говорить',
#  'Говорю',
#  'Говорят,',
#  'Голландии,',
#  'Голова',
#  'Голова...',
#  'Голос',
#  'Голоса',
#  'Голубой',
#  'Гольдшмидт',
#  'Гольдшмидта"',
#  'Гольфстрим',
#  'Гольфстрим!',
#  'Гольфстрим!..',
#  'Гольфстрим,',
#  'Гольфстрим.',
#  'Гольфстрима!',
#  'Гольфстрима,',
#  'Гольфстрима...',
#  'Гольфстримом',
#  'Гольфстриму',
#  'Гольфстриму.']

# %% [markdown]
# ## 1. Более умный способ: сегментируем текст регекспом

# %%
## питоновский модуль для регекспов
## ВООБЩЕ-ТО так делать НЕХОРОШО, потому что в тетрадках положено все импорты пихать в самую верхнюю ячейку
## но я считаю, что здесь в педагогических целях можно
import re

# %%
dva_okeana_spisok_re =  re.split ('( +|[.,!?–]|\n)',dva_okeana_kak_stroka)

# %%
dva_okeana_spisok_re [:100]
# Out:
# ['*',
#  ' ',
#  'ЧАСТЬ',
#  ' ',
#  'ПЕРВАЯ',
#  ' ',
#  '*',
#  ' ',
#  '',
#  '\n',
#  'Глава',
#  ' ',
#  'I',
#  '.',
#  '',
#  ' ',
#  'ПРЕРВАННЫЙ',
#  ' ',
#  'РАЗГОВОР',
#  '\n',
#  '',
#  ' ',
#  'До',
#  ' ',
#  'рассвета',
#  ' ',
#  'оставалось',
#  ' ',
#  'уже',
#  ' ',
#  'немного',
#  '.',
#  '',
#  ' ',
#  'Из',
#  ' ',
#  'комнаты',
#  ' ',
#  'на',
#  ' ',
#  'четырнадцатом',
#  ' ',
#  'этаже',
#  ',',
#  '',
#  '\n',
#  'сквозь',
#  ' ',
#  'щелку',
#  ' ',
#  'между',
#  ' ',
#  'плотными',
#  ' ',
#  'портьерами',
#  ',',
#  '',
#  ' ',
#  'во',
#  ' ',
#  'влажную',
#  ' ',
#  'темноту',
#  ' ',
#  'двора',
#  ' ',
#  'пробивалась',
#  '\n',
#  'слабая',
#  ',',
#  '',
#  ' ',
#  'едва',
#  ' ',
#  'заметная',
#  ' ',
#  'полоска',
#  ' ',
#  'света',
#  '.',
#  '',
#  '\n',
#  '',
#  ' ',
#  'Маленькая',
#  ' ',
#  'настольная',
#  ' ',
#  'лампа',
#  ' ',
#  'под',
#  ' ',
#  'низким',
#  ' ',
#  'черным',
#  ' ',
#  'абажуром',
#  ' ',
#  'бросала',
#  ' ']

# %% [markdown]
# ## 2. Еще более умный способ: сегментируем текст готовым токенизатором — возьмем его из прекрасной библиотеки для обработки языка NLTK

# %%
# если у вас еще нет nltk, установите его:
# !pip install nltk

# %%
from nltk.tokenize import word_tokenize
clean_prest_i_nak_kak_stroka = re.sub ('[.,?!-:]', '', prest_i_nak_kak_stroka)
prest_i_nak_nltk_tokenized = word_tokenize (clean_prest_i_nak_kak_stroka)

# %%
prest_i_nak_nltk_tokenized [:100]

# %% [markdown]
# ### А теперь давайте посчитаем частотность слов в нашем списке слов; т.е. собственно как часто повторяется каждое

# %%
## для этого мы тоже не станем писать свое решение с нуля, а воспользуемся готовым от NLTK
## возьеме токенизированный список — и засунем его в функцию FreqDist от NLTK
from nltk import FreqDist
word_freqs_prest_i_nak = FreqDist(prest_i_nak_nltk_tokenized)
word_freqs_prest_i_nak.most_common (100)

# %%
word_freqs_prest_i_nak.plot(50, cumulative=False)

# %% [markdown]
# # Стемминг, лемматизация, морфологический анализ

# %% [markdown]
# ### В том же NLTK есть готовая реализация стеммера для русского языка. Давайте потестируем ее!

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("russian")

# %%
## стеммер не быстрый, поэтому давайте возьмем первые 1000 слов, а не все
first_1000 = prest_i_nak_nltk_tokenized[:1000]
## этот стеммер не умеет сам токенизировать -- он работает только с отдельными словами. 
## Поэтому придется скармливать ему наш список по одному: 
prest_i_nak_first_1000_stemmed = []
for word in first_1000:
    prest_i_nak_first_1000_stemmed.append (stemmer.stem(word))

# %%
en_stemmer = SnowballStemmer("english")
string = 'I love teaching students at ITMO'
tostem = string.split()
for word in tostem:
    print (en_stemmer.stem(word))

# %%
prest_i_nak_first_1000_stemmed
